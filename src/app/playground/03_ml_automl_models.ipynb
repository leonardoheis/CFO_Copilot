# %% [markdown]
# # ML + AutoML (LinearRegression, PyCaret, StatsForecast)
#
# **Input:** Feature matrix from 01
#
# **Output:** Fitted ML forecasts per company
#
# _Status: planned — boundaries only._

# %% [markdown]
# ## 1. LinearRegression pipeline
#
# TODO

# %% [markdown]
# ## 2. AutoML comparison
#
# TODO

# %% [markdown]
# ## 3. Forecasts
#
# TODO
