# %% [markdown]
# # Validation, Backtest + Mapie prediction intervals
#
# **Input:** Forecasts from 02-04
#
# **Output:** Metric table, model ranking, prediction intervals
#
# _Status: planned — boundaries only._

# %% [markdown]
# ## 1. Time-series split / rolling backtest
#
# TODO

# %% [markdown]
# ## 2. Metrics (MAPE, RMSE)
#
# TODO

# %% [markdown]
# ## 3. Mapie intervals
#
# TODO

# %% [markdown]
# ## 4. Model ranking
#
# TODO
