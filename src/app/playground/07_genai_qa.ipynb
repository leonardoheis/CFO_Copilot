# %% [markdown]
# # GenAI Q&A
#
# **Input:** Forecasts and reports
#
# **Output:** Contextual answers about forecasts and charts
#
# _Status: planned — boundaries only._

# %% [markdown]
# ## 1. Document / forecast context
#
# TODO

# %% [markdown]
# ## 2. LangChain + LLM chain
#
# TODO

# %% [markdown]
# ## 3. Example queries
#
# TODO
