# %% [markdown]
# # Registry + Predict pipeline (ensemble, bootstrap CI)
#
# **Input:** Ranked models from 05
#
# **Output:** Registered artifacts, ensemble prediction with CI
#
# _Status: planned — boundaries only._

# %% [markdown]
# ## 1. Register artifacts (MLflow / W&B)
#
# TODO

# %% [markdown]
# ## 2. Preprocessing
#
# TODO

# %% [markdown]
# ## 3. Ensemble prediction
#
# TODO

# %% [markdown]
# ## 4. Bootstrap CI
#
# TODO
