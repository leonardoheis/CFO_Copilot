# %% [markdown]
# # LSTM
#
# **Input:** Feature matrix from 01
#
# **Output:** Fitted LSTM forecasts per company
#
# _Status: planned — boundaries only._

# %% [markdown]
# ## 1. Windowing and scaling
#
# TODO

# %% [markdown]
# ## 2. Model definition
#
# TODO

# %% [markdown]
# ## 3. Training
#
# TODO

# %% [markdown]
# ## 4. Forecasts
#
# TODO
