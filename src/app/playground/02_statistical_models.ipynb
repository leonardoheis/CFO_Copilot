# %% [markdown]
# # ARIMA / SARIMA
#
# **Input:** Feature matrix from 01
#
# **Output:** Fitted statistical forecasts per company
#
# _Status: planned — boundaries only._

# %% [markdown]
# ## 1. Baseline (naive / seasonal naive)
#
# TODO

# %% [markdown]
# ## 2. ARIMA order selection
#
# TODO

# %% [markdown]
# ## 3. SARIMA
#
# TODO

# %% [markdown]
# ## 4. Forecasts
#
# TODO
